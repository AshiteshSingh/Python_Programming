# %%
#objectname = classname()

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    #print(id(self))
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin():
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj=Atm()
# Out:
# pin created successfully
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
class temp:
    def __init__(self):
        print('arpan')
obj=temp()
# Out:
# arpan

# %%
3/4*1/2
# Out:
# 0.375

# %%
class Fraction:
    def __init__(self,x,y):
      self.num=x
      self.den=y
dr1=Fraction(2,3)

# %%
# Define the Vehicle class
class Vehicle:
    # __init__ is the constructor method
    def __init__(self, max_speed, mileage):
        # Create instance attributes using self
        self.max_speed = max_speed
        self.mileage = mileage

# Create different Vehicle objects
car1 = Vehicle(180, 25000)
car2 = Vehicle(220, 15000)
bike = Vehicle(120, 8000)

# Access the attributes
print(f"Car 1 - Max Speed: {car1.max_speed}, Mileage: {car1.mileage}")
print(f"Car 2 - Max Speed: {car2.max_speed}, Mileage: {car2.mileage}")
print(f"Bike - Max Speed: {bike.max_speed}, Mileage: {bike.mileage}")
# Out:
# Car 1 - Max Speed: 180, Mileage: 25000
# Car 2 - Max Speed: 220, Mileage: 15000
# Bike - Max Speed: 120, Mileage: 8000

# %% [markdown]
# STUDENT MANAGEMENT

# %%
class Student:
    def __init__(self,name,age,grade):
        self.name=name
        self.age=age
        self.grade=grade
student1=Student('rahul',14,90)
student2=Student('rohan',16,90)
student3=Student('sam',16,0)

print(f"1st Student name: {student1.name},Age: {student1.age}:Grade: {student1.grade}")
print(f"2nd Student name: {student2.name},Age: {student2.age}:Grade: {student2.grade}")
print(f"3rd Student name: {student3.name},Age: {student3.age}:Grade: {student3.grade}")
# Out:
# 1st Student name: rahul,Age: 14:Grade: 90
# 2nd Student name: rohan,Age: 16:Grade: 90
# 3rd Student name: sam,Age: 16:Grade: 0

# %% [markdown]
# CALCULATOR

# %%
class Calculator:
    def __init__(self):
     def menu(self):
       user_input=input("""
        add keliye 1 daba
        multi ke liye 2 daba
        minu ke liye 3 daba
        div ke liye 4 daba
        agar calculate nahi karna toh bhaag yahan se
        """)
       if user_input==1: 
         self.sum
       elif user_input==2:
         self.minus
       elif user_input==3:
         self.multi
       elif user_input==4:
         self.div
       else:
         exit()
    def sum(*args):
             add=0
             if i in args:
               i+=add
               print(i)
    sum()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 class Calculator:
#       2     def __init__(self):
#       3      def menu(self):
#
# Cell In[28], line 26, in Calculator()
#      24            i+=add
#      25            print(i)
# ---> 26 sum()
#
# Cell In[28], line 23, in Calculator.sum(*args)
#      21 def sum(*args):
#      22          add=0
# ---> 23          if i in args:
#      24            i+=add
#      25            print(i)
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %%
class Calculator:

    def __init__(self):
        self.num1 = 0
        self.num2 = 0

    def get_numbers(self):
        self.num1 = float(input("chal number daal: "))
        self.num2 = float(input("chal dusra number daal: "))

    def add(self):
        result = self.num1 + self.num2
        print(f'answer of add is: {result}')

    def minus(self):
        result = self.num1 - self.num2
        print(f'answer minus ka: {result}')

    def multi(self):
        result = self.num1 * self.num2
        print(f'multi ka answer hai: {result}')

    def div(self):
        if self.num2 != 0:
            result = self.num1 / self.num2
            print(f'div ka result hai: {result}')
        else:
            print('Zero se divide nahi kar sakte!')

    def menu(self):
        while True:
            user_input = input("""
            1-add karo
            2-minus karo
            3-multi karo
            4-div karo
            5-bhhaag yahan se!!
            Apna choice: """)
            if user_input == '1':
                self.get_numbers()
                self.add()
            elif user_input == '2':
                self.get_numbers()
                self.minus()
            elif user_input == '3':
                self.get_numbers()
                self.multi()
            elif user_input == '4':
                self.get_numbers()
                self.div()
            elif user_input == '5':
                print('bhaag yahan se')
                break
            else:
                print('gawar sahi number dalne nahi aata')
calc=Calculator()
calc.menu()
# Out:
# answer of add is: 65.0
# gawar sahi number dalne nahi aata
# gawar sahi number dalne nahi aata
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 57
#      55                 print('gawar sahi number dalne nahi aata')
#      56 calc=Calculator()
# ---> 57 calc.menu()
#
# Cell In[9], line 32, in Calculator.menu(self)
#      30 def menu(self):
#      31     while True:
# ---> 32         user_input = input("""
#      33         1-add karo
#      34         2-minus karo
#      35         3-multi karo
#      36         4-div karo
#      37         5-bhhaag yahan se!!
#      38         Apna choice: """)
#      39         if user_input == '1':
#      40             self.get_numbers()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1473, in Kernel.raw_input(self, prompt)
# ...

# %%
class Calculator:
    def __init__(self):
        self.numbers = []

    def get_numbers(self):
        while True:
            num = input("Enter a number (or 'done' to finish): ")
            if num.lower() == 'done':
                if len(self.numbers) < 2:
                    print("Please enter at least 2 numbers!")
                    self.numbers = []
                    continue
                break
            try:
                self.numbers.append(float(num))
            except ValueError:
                print("Please enter a valid number!")

    def add(self):
        result = sum(self.numbers)
        print(f'Sum of {self.numbers} is: {result}')

    def minus(self):
        result = self.numbers[0]
        for num in self.numbers[1:]:
            result -= num
        print(f'Subtraction result of {self.numbers} is: {result}')

    def multi(self):
        result = 1
        for num in self.numbers:
            result *= num
        print(f'Multiplication of {self.numbers} is: {result}')

    def div(self):
        result = self.numbers[0]
        try:
            for num in self.numbers[1:]:
                if num == 0:
                    raise ZeroDivisionError
                result /= num
            print(f'Division result of {self.numbers} is: {result}')
        except ZeroDivisionError:
            print('Cannot divide by zero!')

    def menu(self):
        while True:
            user_input = input("""
            1-add multiple numbers
            2-minus multiple numbers
            3-multiply multiple numbers
            4-divide multiple numbers
            5-exit
            Your choice: """)
            
            if user_input in ['1', '2', '3', '4']:
                self.numbers = []  # Reset numbers list
                self.get_numbers()
                if user_input == '1':
                    self.add()
                elif user_input == '2':
                    self.minus()
                elif user_input == '3':
                    self.multi()
                elif user_input == '4':
                    self.div()
            elif user_input == '5':
                print('Goodbye!')
                break
            else:
                print('Invalid choice! Try again.')

calc = Calculator()
calc.menu()
